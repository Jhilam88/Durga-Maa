# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x=np.linspace(-2.5,2.5,40)
y=(2**x)
z=np.linspace(-7.5,-2.5,40)
w=(.5**x)
plt.axis("scaled")
plt.axis("equal")
plt.plot(x,y,"black")
plt.plot(z,w,"black")
plt.show()

# %%
x=np.linspace(-2.5,2.5,40)
y=(2**x)
z=np.linspace(-7.5,-2.5,40)
w=(.5**x)
a=np.linspace(-1,2,40)
b=-(0.6**a)+6
plt.axis("scaled")
plt.axis("equal")
plt.plot(x,y,"black")
plt.plot(z,w,"black")
plt.plot(a,b,"black",linewidth=6)
plt.show()

# %%
x=np.linspace(-2.5,2.5,40)
y=(2**x)
z=np.linspace(-7.5,-2.5,40)
w=(.5**x)
a=np.linspace(-1,2,40)
b=-(0.6**a)+6
e=np.linspace(-1,2,40)
f=-(.6**e)+5.5
plt.axis("scaled")
plt.axis("equal")
plt.plot(x,y,"black")
plt.plot(z,w,"black")
plt.plot(a,b,"black",linewidth=6)
plt.plot(e,f,"black")
plt.show()

# %%
x=np.linspace(-2.5,2.5,40)
y=(2**x)
z=np.linspace(-7.5,-2.5,40)
w=(.5**x)
a=np.linspace(-1,2,40)
b=-(0.6**a)+6
e=np.linspace(-1,2,40)
f=-(.6**e)+5.5
c=np.linspace(-2.5,2.5,40)
d=(.7**c)+5.5
plt.axis("scaled")
plt.axis("equal")
plt.plot(x,y,"black")
plt.plot(z,w,"black")
plt.plot(a,b,"black",linewidth=6)
plt.plot(e,f,"black")
plt.plot(c,d,"black",linewidth=3)
plt.show()

# %%
x=np.linspace(-2.5,2.5,40)
y=(2**x)
z=np.linspace(-7.5,-2.5,40)
w=(.5**x)
a=np.linspace(-1,2,40)
b=-(0.6**a)+6
e=np.linspace(-1,2,40)
f=-(.6**e)+5.5
c=np.linspace(-2.5,2.5,40)
d=(.7**c)+5.5
g=np.linspace(-7.5,-2.5,40)
h=(1/((.7)**c))+5.5
plt.axis("scaled")
plt.axis("equal")
plt.plot(x,y,"black",linewidth=3)
plt.plot(z,w,"black",linewidth=3)
plt.plot(a,b,"black",linewidth=6)
plt.plot(e,f,"black")
plt.plot(c,d,"black",linewidth=3)
plt.plot(g,h,"black",linewidth=3)
plt.show()

# %%
x=np.linspace(-2.5,2.5,40)
y=(2**x)
z=np.linspace(-7.5,-2.5,40)
w=(.5**x)
a=np.linspace(-1,2,40)
b=-(0.6**a)+6
i=np.linspace(-7,-4,40)
j=-(.6/(.6**a))+6
e=np.linspace(-1,2,40)
f=-(.6**e)+5.5
c=np.linspace(-2.5,2.5,40)
d=(.7**c)+5.5
g=np.linspace(-7.5,-2.5,40)
h=(1/((.7)**c))+5.5
plt.axis("scaled")
plt.axis("equal")
plt.plot(x,y,"black",linewidth=3)
plt.plot(z,w,"black",linewidth=3)
plt.plot(a,b,"black",linewidth=6)
plt.plot(e,f,"black")
plt.plot(c,d,"black",linewidth=3)
plt.plot(g,h,"black",linewidth=3)
plt.plot(i,j,"black",linewidth=6)
plt.show()

# %%
x=np.linspace(-2.5,2.5,40)
y=(2**x)
z=np.linspace(-7.5,-2.5,40)
w=(.5**x)
a=np.linspace(-1,2,40)
b=-(0.6**a)+6
i=np.linspace(-7,-4,40)
j=-(.6/(.6**a))+6
e=np.linspace(-1,2,40)
f=-(.6**e)+5.5
k=np.linspace(-7,-4,40)
l=-(.6/(.6**e))+5.5
c=np.linspace(-2.5,2.5,40)
d=(.7**c)+5.5
g=np.linspace(-7.5,-2.5,40)
h=(1/((.7)**c))+5.5
plt.axis("scaled")
plt.axis("equal")
plt.plot(x,y,"black",linewidth=3)
plt.plot(z,w,"black",linewidth=3)
plt.plot(a,b,"black",linewidth=6)
plt.plot(e,f,"black")
plt.plot(c,d,"black",linewidth=3)
plt.plot(g,h,"black",linewidth=3)
plt.plot(i,j,"black",linewidth=6)
plt.plot(k,l,"black")
plt.show()

# %%
x=np.linspace(-2.5,2.5,40)
y=(2**x)
z=np.linspace(-7.5,-2.5,40)
w=(.5**x)
a=np.linspace(-1,2,40)
b=-(0.6**a)+6
i=np.linspace(-7,-4,40)
j=-(.6/(.6**a))+6
e=np.linspace(-1,2,40)
f=-(.6**e)+5.5
k=np.linspace(-7,-4,40)
l=-(.6/(.6**e))+5.5
c=np.linspace(-2.5,2.5,40)
d=(.7**c)+5.5
g=np.linspace(-7.5,-2.5,40)
h=(1/((.7)**c))+5.5
circle1=plt.Circle((-2.5,5),radius=.35,color="r")
ax=plt.gca()
ax.add_patch(circle1)
plt.axis("scaled")
plt.axis("equal")
plt.plot(x,y,"black",linewidth=3)
plt.plot(z,w,"black",linewidth=3)
plt.plot(a,b,"black",linewidth=6)
plt.plot(e,f,"black")
plt.plot(c,d,"black",linewidth=3)
plt.plot(g,h,"black",linewidth=3)
plt.plot(i,j,"black",linewidth=6)
plt.plot(k,l,"black")
plt.show()

# %%
x=np.linspace(-2.5,2.5,40)
y=(2**x)
z=np.linspace(-7.5,-2.5,40)
w=(.5**x)
a=np.linspace(-1,2,40)
b=-(0.6**a)+6
i=np.linspace(-7,-4,40)
j=-(.6/(.6**a))+6
e=np.linspace(-1,2,40)
f=-(.6**e)+5.5
k=np.linspace(-7,-4,40)
l=-(.6/(.6**e))+5.5
c=np.linspace(-2.5,2.5,40)
d=(.7**c)+5.5
g=np.linspace(-7.5,-2.5,40)
h=(1/((.7)**c))+5.5
m=np.linspace(0,2,40)
n=m+3
o=np.linspace(-5,-7,40)
p=-o-2
circle1=plt.Circle((-2.5,5),radius=.35,color="r")
ax=plt.gca()
ax.add_patch(circle1)
plt.axis("scaled")
plt.axis("equal")
plt.plot(x,y,"black",linewidth=3)
plt.plot(z,w,"black",linewidth=3)
plt.plot(a,b,"black",linewidth=6)
plt.plot(e,f,"black")
plt.plot(c,d,"black",linewidth=3)
plt.plot(g,h,"black",linewidth=3)
plt.plot(i,j,"black",linewidth=6)
plt.plot(k,l,"black")
plt.plot(m,n,"black")
plt.plot(o,p,"black")
plt.show()

# %%
x=np.linspace(-2.5,2.5,40)
y=(2**x)
z=np.linspace(-7.5,-2.5,40)
w=(.5**x)
a=np.linspace(-1,2,40)
b=-(0.6**a)+6
i=np.linspace(-7,-4,40)
j=-(.6/(.6**a))+6
e=np.linspace(-1,2,40)
f=-(.6**e)+5.5
k=np.linspace(-7,-4,40)
l=-(.6/(.6**e))+5.5
c=np.linspace(-2.5,2.5,40)
d=(.7**c)+5.5
g=np.linspace(-7.5,-2.5,40)
h=(1/((.7)**c))+5.5
m=np.linspace(0,2,40)
n=m+3
o=np.linspace(-5,-7,40)
p=-o-2
q=np.linspace(-1,0,40)
r=(.6**q)+2
s=np.linspace(-4,-5,40)
t=-(1.3/(.5**q))+4.3
circle1=plt.Circle((-2.5,5),radius=.35,color="r")
ax=plt.gca()
ax.add_patch(circle1)
plt.axis("scaled")
plt.axis("equal")
plt.plot(x,y,"black",linewidth=3)
plt.plot(z,w,"black",linewidth=3)
plt.plot(a,b,"black",linewidth=6)
plt.plot(e,f,"black")
plt.plot(c,d,"black",linewidth=3)
plt.plot(g,h,"black",linewidth=3)
plt.plot(i,j,"black",linewidth=6)
plt.plot(k,l,"black")
plt.plot(m,n,"black")
plt.plot(o,p,"black")
plt.plot(q,r,"black")
plt.plot(s,t,"black")
plt.show()

# %%
x=np.linspace(-2.5,2.5,40)
y=(2**x)
z=np.linspace(-7.5,-2.5,40)
w=(.5**x)
a=np.linspace(-1,2,40)
b=-(0.6**a)+6
i=np.linspace(-7,-4,40)
j=-(.6/(.6**a))+6
e=np.linspace(-1,2,40)
f=-(.6**e)+5.5
k=np.linspace(-7,-4,40)
l=-(.6/(.6**e))+5.5
c=np.linspace(-2.5,2.5,40)
d=(.7**c)+5.5
g=np.linspace(-7.5,-2.5,40)
h=(1/((.7)**c))+5.5
m=np.linspace(0,2,40)
n=m+3
o=np.linspace(-5,-7,40)
p=-o-2
q=np.linspace(-1,0,40)
r=(.6**q)+2
s=np.linspace(-4,-5,40)
t=-(1.3/(.5**q))+4.3
circle1=plt.Circle((-2.5,5),radius=.35,color="r")
circle2=plt.Circle((0,3.8),radius=.5,color="black")
circle3=plt.Circle((-5,3.8),radius=.5,color="black")
ax=plt.gca()
ax.add_patch(circle1)
ax.add_patch(circle2)
ax.add_patch(circle3)
plt.axis("scaled")
plt.axis("equal")
plt.plot(x,y,"black",linewidth=3)
plt.plot(z,w,"black",linewidth=3)
plt.plot(a,b,"black",linewidth=6)
plt.plot(e,f,"black")
plt.plot(c,d,"black",linewidth=3)
plt.plot(g,h,"black",linewidth=3)
plt.plot(i,j,"black",linewidth=6)
plt.plot(k,l,"black")
plt.plot(m,n,"black")
plt.plot(o,p,"black")
plt.plot(q,r,"black")
plt.plot(s,t,"black")
plt.show()

# %%
x=np.linspace(-2.5,2.5,40)
y=(2**x)
z=np.linspace(-7.5,-2.5,40)
w=(.5**x)
a=np.linspace(-1,2,40)
b=-(0.6**a)+6
i=np.linspace(-7,-4,40)
j=-(.6/(.6**a))+6
e=np.linspace(-1,2,40)
f=-(.6**e)+5.5
k=np.linspace(-7,-4,40)
l=-(.6/(.6**e))+5.5
c=np.linspace(-2.5,2.5,40)
d=(.7**c)+5.5
g=np.linspace(-7.5,-2.5,40)
h=(1/((.7)**c))+5.5
m=np.linspace(0,2,40)
n=m+3
o=np.linspace(-5,-7,40)
p=-o-2
q=np.linspace(-1,0,40)
r=(.6**q)+2
s=np.linspace(-4,-5,40)
t=-(1.3/(.5**q))+4.3
u=np.linspace(-3.5,-1.5,40)
v=((x/3)**2)+5
circle1=plt.Circle((-2.5,4.3),radius=.35,edgecolor="r",facecolor="r",linewidth=3)
circle2=plt.Circle((0,3.8),radius=.5,color="black")
circle3=plt.Circle((-5,3.8),radius=.5,color="black")
ax=plt.gca()
ax.add_patch(circle1)
ax.add_patch(circle2)
ax.add_patch(circle3)
plt.axis("scaled")
plt.axis("equal")
plt.plot(x,y,"black",linewidth=3)
plt.plot(z,w,"black",linewidth=3)
plt.plot(a,b,"black",linewidth=6)
plt.plot(e,f,"black")
plt.plot(c,d,"black",linewidth=3)
plt.plot(g,h,"black",linewidth=3)
plt.plot(i,j,"black",linewidth=6)
plt.plot(k,l,"black")
plt.plot(m,n,"black")
plt.plot(o,p,"black")
plt.plot(q,r,"black")
plt.plot(s,t,"black")
plt.plot(u,v,"black")
plt.show()

# %%
x=np.linspace(-2.5,2.5,40)
y=(2**x)
z=np.linspace(-7.5,-2.5,40)
w=(.5**x)
a=np.linspace(-1,2,40)
b=-(0.6**a)+6
i=np.linspace(-7,-4,40)
j=-(.6/(.6**a))+6
e=np.linspace(-1,2,40)
f=-(.6**e)+5.5
k=np.linspace(-7,-4,40)
l=-(.6/(.6**e))+5.5
c=np.linspace(-2.5,2.5,40)
d=(.7**c)+5.5
g=np.linspace(-7.5,-2.5,40)
h=(1/((.7)**c))+5.5
m=np.linspace(0,2,40)
n=m+3
o=np.linspace(-5,-7,40)
p=-o-2
q=np.linspace(-1,0,40)
r=(.6**q)+2
s=np.linspace(-4,-5,40)
t=-(1.3/(.5**q))+4.3
u=np.linspace(-3.5,-1.5,40)
v=((x/3)**2)+5
s1=np.linspace(-2.5,-3,40)
t1=-(o/5)+1
u1=np.linspace(-2,-2.5,40)
v1=(u1/1)+4.5
circle1=plt.Circle((-2.5,4.3),radius=.35,edgecolor="r",facecolor="r",linewidth=3)
circle2=plt.Circle((0,3.8),radius=.5,color="black")
circle3=plt.Circle((-5,3.8),radius=.5,color="black")
ax=plt.gca()
ax.add_patch(circle1)
ax.add_patch(circle2)
ax.add_patch(circle3)
plt.axis("scaled")
plt.axis("equal")
plt.plot(x,y,"black",linewidth=3)
plt.plot(z,w,"black",linewidth=3)
plt.plot(a,b,"black",linewidth=6)
plt.plot(e,f,"black")
plt.plot(c,d,"black",linewidth=3)
plt.plot(g,h,"black",linewidth=3)
plt.plot(i,j,"black",linewidth=6)
plt.plot(k,l,"black")
plt.plot(m,n,"black")
plt.plot(o,p,"black")
plt.plot(q,r,"black")
plt.plot(s,t,"black")
plt.plot(u,v,"black")
plt.plot(s1,t1,"black")
plt.plot(u1,v1,"black")
plt.show()

# %%
x=np.linspace(-2.5,2.5,40)
y=(2**x)
z=np.linspace(-7.5,-2.5,40)
w=(.5**x)
a=np.linspace(-1,2,40)
b=-(0.6**a)+6
i=np.linspace(-7,-4,40)
j=-(.6/(.6**a))+6
e=np.linspace(-1,2,40)
f=-(.6**e)+5.5
k=np.linspace(-7,-4,40)
l=-(.6/(.6**e))+5.5
c=np.linspace(-2.5,2.5,40)
d=(.7**c)+5.5
g=np.linspace(-7.5,-2.5,40)
h=(1/((.7)**c))+5.5
m=np.linspace(0,2,40)
n=m+3
o=np.linspace(-5,-7,40)
p=-o-2
q=np.linspace(-1,0,40)
r=(.6**q)+2
s=np.linspace(-4,-5,40)
t=-(1.3/(.5**q))+4.3
u=np.linspace(-3.5,-1.5,40)
v=((x/3)**2)+5
s1=np.linspace(-2.5,-3,40)
t1=-(o/5)+1
u1=np.linspace(-2,-2.5,40)
v1=(u1/1)+4.5
circle1=plt.Circle((-2.5,4.3),radius=.35,edgecolor="r",facecolor="r",linewidth=3)
circle2=plt.Circle((0,3.8),radius=.5,color="black")
circle3=plt.Circle((-5,3.8),radius=.5,color="black")
circle4=plt.Circle((-1.5,2.5),radius=.76,edgecolor="orange",facecolor="w",linewidth=2)
circle5=plt.Circle((-1.5,1.7),radius=.09,color="r")
circle6=plt.Circle((-1.2,1.76),radius=.09,color="r")
circle7=plt.Circle((-.94,1.9),radius=.09,color="r")
ax=plt.gca()
ax.add_patch(circle1)
ax.add_patch(circle2)
ax.add_patch(circle3)
ax.add_patch(circle4)
ax.add_patch(circle5)
ax.add_patch(circle6)
ax.add_patch(circle7)
plt.axis("scaled")
plt.axis("equal")
plt.plot(x,y,"black",linewidth=3)
plt.plot(z,w,"black",linewidth=3)
plt.plot(a,b,"black",linewidth=6)
plt.plot(e,f,"black")
plt.plot(c,d,"black",linewidth=3)
plt.plot(g,h,"black",linewidth=3)
plt.plot(i,j,"black",linewidth=6)
plt.plot(k,l,"black")
plt.plot(m,n,"black")
plt.plot(o,p,"black")
plt.plot(q,r,"black")
plt.plot(s,t,"black")
plt.plot(u,v,"black")
plt.plot(s1,t1,"black")
plt.plot(u1,v1,"black")
plt.show()

# %%
x=np.linspace(-2.5,2.5,40)
y=(2**x)
z=np.linspace(-7.5,-2.5,40)
w=(.5**x)
a=np.linspace(-1,2,40)
b=-(0.6**a)+6
i=np.linspace(-7,-4,40)
j=-(.6/(.6**a))+6
e=np.linspace(-1,2,40)
f=-(.6**e)+5.5
k=np.linspace(-7,-4,40)
l=-(.6/(.6**e))+5.5
c=np.linspace(-2.5,2.5,40)
d=(.7**c)+5.5
g=np.linspace(-7.5,-2.5,40)
h=(1/((.7)**c))+5.5
m=np.linspace(0,2,40)
n=m+3
o=np.linspace(-5,-7,40)
p=-o-2
q=np.linspace(-1,0,40)
r=(.6**q)+2
s=np.linspace(-4,-5,40)
t=-(1.3/(.5**q))+4.3
u=np.linspace(-3.5,-1.5,40)
v=((x/3)**2)+5
s1=np.linspace(-2.5,-3,40)
t1=-(o/5)+1
u1=np.linspace(-2,-2.5,40)
v1=(u1/1)+4.5
circle1=plt.Circle((-2.5,4.3),radius=.35,edgecolor="r",facecolor="r",linewidth=3)
circle2=plt.Circle((0,3.8),radius=.5,color="black")
circle3=plt.Circle((-5,3.8),radius=.5,color="black")
circle4=plt.Circle((-1.5,2.5),radius=.76,edgecolor="orange",facecolor="w",linewidth=2)
circle5=plt.Circle((-1.5,1.7),radius=.09,color="r")
circle6=plt.Circle((-1.2,1.76),radius=.09,color="r")
circle7=plt.Circle((-.94,1.9),radius=.09,color="r")
circle8=plt.Circle((-2.5,6),radius=.5,color="black")
ax=plt.gca()
ax.add_patch(circle1)
ax.add_patch(circle2)
ax.add_patch(circle3)
ax.add_patch(circle4)
ax.add_patch(circle5)
ax.add_patch(circle6)
ax.add_patch(circle7)
ax.add_patch(circle8)
plt.axis("scaled")
plt.axis("equal")
plt.plot(x,y,"black",linewidth=3)
plt.plot(z,w,"black",linewidth=3)
plt.plot(a,b,"black",linewidth=6)
plt.plot(e,f,"black")
plt.plot(c,d,"black",linewidth=3)
plt.plot(g,h,"black",linewidth=3)
plt.plot(i,j,"black",linewidth=6)
plt.plot(k,l,"black")
plt.plot(m,n,"black")
plt.plot(o,p,"black")
plt.plot(q,r,"black")
plt.plot(s,t,"black")
plt.plot(u,v,"black")
plt.plot(s1,t1,"black")
plt.plot(u1,v1,"black")
plt.show()

# %%
x=np.linspace(-2.5,2.5,40)
y=(2**x)
z=np.linspace(-7.5,-2.5,40)
w=(.5**x)
a=np.linspace(-1,2,40)
b=-(0.6**a)+6
i=np.linspace(-7,-4,40)
j=-(.6/(.6**a))+6
e=np.linspace(-1,2,40)
f=-(.6**e)+5.5
k=np.linspace(-7,-4,40)
l=-(.6/(.6**e))+5.5
c=np.linspace(-2.5,2.5,40)
d=(.7**c)+5.5
g=np.linspace(-7.5,-2.5,40)
h=(1/((.7)**c))+5.5
m=np.linspace(0,2,40)
n=m+3
o=np.linspace(-5,-7,40)
p=-o-2
q=np.linspace(-1,0,40)
r=(.6**q)+2
s=np.linspace(-4,-5,40)
t=-(1.3/(.5**q))+4.3
u=np.linspace(-3.5,-1.5,40)
v=((x/3)**2)+5
s1=np.linspace(-2.5,-3,40)
t1=-(o/5)+1
u1=np.linspace(-2,-2.5,40)
v1=(u1/1)+4.5
A=np.linspace(-1.5,-2.5,40)
B=(x/3)+6.5
C=np.linspace(-3.5,-2.5,40)
D=(C/.65)+11.1
circle1=plt.Circle((-2.5,4.3),radius=.35,edgecolor="r",facecolor="r",linewidth=3)
circle2=plt.Circle((0,3.8),radius=.5,color="black")
circle3=plt.Circle((-5,3.8),radius=.5,color="black")
circle4=plt.Circle((-1.5,2.5),radius=.8,edgecolor="orange",facecolor="w",linewidth=2)
circle5=plt.Circle((-1.5,1.7),radius=.09,color="r")
circle6=plt.Circle((-1.2,1.76),radius=.09,color="r")
circle7=plt.Circle((-.94,1.9),radius=.09,color="r")
circle8=plt.Circle((-2.5,5.7),radius=.5,color="black")
ax=plt.gca()
ax.add_patch(circle1)
ax.add_patch(circle2)
ax.add_patch(circle3)
ax.add_patch(circle4)
ax.add_patch(circle5)
ax.add_patch(circle6)
ax.add_patch(circle7)
ax.add_patch(circle8)
plt.axis("scaled")
plt.axis("equal")
plt.plot(x,y,"black",linewidth=3)
plt.plot(z,w,"black",linewidth=3)
plt.plot(a,b,"black",linewidth=6)
plt.plot(e,f,"black")
plt.plot(c,d,"black",linewidth=3)
plt.plot(g,h,"black",linewidth=3)
plt.plot(i,j,"black",linewidth=6)
plt.plot(k,l,"black")
plt.plot(m,n,"black")
plt.plot(o,p,"black")
plt.plot(q,r,"black")
plt.plot(s,t,"black")
plt.plot(u,v,"black",linewidth=2)
plt.plot(s1,t1,"black")
plt.plot(u1,v1,"black")
plt.plot(A,B,"black",linewidth=2)
plt.plot(C,D,"black",linewidth=2)
plt.show()

# %%
x=np.linspace(-2.5,2.5,40)
y=(2**x)
z=np.linspace(-7.5,-2.5,40)
w=(.5**x)
a=np.linspace(-1,2,40)
b=-(0.6**a)+6
i=np.linspace(-7,-4,40)
j=-(.6/(.6**a))+6
e=np.linspace(-1,2,40)
f=-(.6**e)+5.5
k=np.linspace(-7,-4,40)
l=-(.6/(.6**e))+5.5
c=np.linspace(-2.5,2.5,40)
d=(.7**c)+5.5
g=np.linspace(-7.5,-2.5,40)
h=(1/((.7)**c))+5.5
m=np.linspace(0,2,40)
n=m+3
o=np.linspace(-5,-7,40)
p=-o-2
q=np.linspace(-1,0,40)
r=(.6**q)+2
s=np.linspace(-4,-5,40)
t=-(1.3/(.5**q))+4.3
u=np.linspace(-3.5,-1.5,40)
v=((x/3)**2)+5
s1=np.linspace(-2.5,-3,40)
t1=-(o/5)+1
u1=np.linspace(-2,-2.5,40)
v1=(u1/1)+4.5
A=np.linspace(-1.5,-2.5,40)
B=(x/3)+6.5
C=np.linspace(-3.5,-2.5,40)
D=(C/.65)+11.1
E=np.linspace(-3.5,-1.5,40)
F=((x/6)**2)+1.3
G=np.linspace(-3.2,-1.8,40)
H=((x/4)**2)+1
I=np.linspace(-3.2,-1.8,40)
J=((x/4)**2)+3.6
K=np.linspace(-2.3,-2.5,40)
L=(K/2)+2.85
O=np.linspace(-2.5,-2.7,40)
P=-(o/13)+1.18
M=np.linspace(-2.8,-2.2,40)
N=-((x/7)**2)+.75
x1=np.linspace(-2.7,-3.2,40)
y1=(x1/2)+3.08
z1=np.linspace(-2.3,-1.8,40)
w1=-(z1/2)+.6
circle1=plt.Circle((-2.5,4.3),radius=.35,edgecolor="r",facecolor="r",linewidth=3)
circle2=plt.Circle((0,3.8),radius=.5,color="black")
circle3=plt.Circle((-5,3.8),radius=.5,color="black")
circle4=plt.Circle((-1.3,2.5),radius=1,edgecolor="orange",facecolor="w",linewidth=2)
circle5=plt.Circle((-.7,1.69),radius=.09,color="r")
circle6=plt.Circle((-0.5,1.89),radius=.09,color="r")
circle7=plt.Circle((-.94,1.54),radius=.09,color="r")
circle8=plt.Circle((-2.5,5.7),radius=.5,color="black")
ax=plt.gca()
ax.add_patch(circle1)
ax.add_patch(circle2)
ax.add_patch(circle3)
ax.add_patch(circle4)
ax.add_patch(circle5)
ax.add_patch(circle6)
ax.add_patch(circle7)
ax.add_patch(circle8)
plt.axis("scaled")
plt.axis("equal")
plt.plot(x,y,"black",linewidth=3)
plt.plot(z,w,"black",linewidth=3)
plt.plot(a,b,"black",linewidth=6)
plt.plot(e,f,"black")
plt.plot(c,d,"black",linewidth=3)
plt.plot(g,h,"black",linewidth=3)
plt.plot(i,j,"black",linewidth=6)
plt.plot(k,l,"black")
plt.plot(m,n,"black")
plt.plot(o,p,"black")
plt.plot(q,r,"black")
plt.plot(s,t,"black")
plt.plot(u,v,"black",linewidth=2)
plt.plot(s1,t1,"black")
plt.plot(u1,v1,"black")
plt.plot(A,B,"black",linewidth=2)
plt.plot(C,D,"black",linewidth=2)
plt.plot(I,J,"r",linewidth=3)
plt.show()

# %%
x=np.linspace(-2.5,2.5,40)
y=(2**x)
z=np.linspace(-7.5,-2.5,40)
w=(.5**x)
a=np.linspace(-1,2,40)
b=-(0.6**a)+6
i=np.linspace(-7,-4,40)
j=-(.6/(.6**a))+6
e=np.linspace(-1,2,40)
f=-(.6**e)+5.5
k=np.linspace(-7,-4,40)
l=-(.6/(.6**e))+5.5
c=np.linspace(-2.5,2.5,40)
d=(.7**c)+5.5
g=np.linspace(-7.5,-2.5,40)
h=(1/((.7)**c))+5.5
m=np.linspace(0,2,40)
n=m+3
o=np.linspace(-5,-7,40)
p=-o-2
q=np.linspace(-1,0,40)
r=(.6**q)+2
s=np.linspace(-4,-5,40)
t=-(1.3/(.5**q))+4.3
u=np.linspace(-3.5,-1.5,40)
v=((x/3)**2)+5
s1=np.linspace(-2.5,-3,40)
t1=-(o/5)+1
u1=np.linspace(-2,-2.5,40)
v1=(u1/1)+4.5
A=np.linspace(-1.5,-2.5,40)
B=(x/3)+6.5
C=np.linspace(-3.5,-2.5,40)
D=(C/.65)+11.1
E=np.linspace(-3.5,-1.5,40)
F=((x/6)**2)+1.3
G=np.linspace(-3.2,-1.8,40)
H=((x/4)**2)+1
I=np.linspace(-3.2,-1.8,40)
J=((x/4)**2)+3.6
K=np.linspace(-2.3,-2.5,40)
L=(K/2)+2.85
O=np.linspace(-2.5,-2.7,40)
P=-(o/13)+1.18
M=np.linspace(-2.8,-2.2,40)
N=-((x/7)**2)+.75
x1=np.linspace(-2.7,-3.2,40)
y1=(x1/2)+3.08
z1=np.linspace(-2.3,-1.8,40)
w1=-(z1/2)+.6
circle1=plt.Circle((-2.5,4.3),radius=.35,edgecolor="r",facecolor="r",linewidth=3)
circle2=plt.Circle((0,3.8),radius=.5,color="black")
circle3=plt.Circle((-5,3.8),radius=.5,color="black")
circle4=plt.Circle((-1.3,2.5),radius=1,edgecolor="orange",facecolor="w",linewidth=2)
circle5=plt.Circle((-.7,1.69),radius=.09,color="r")
circle6=plt.Circle((-0.5,1.89),radius=.09,color="r")
circle7=plt.Circle((-.94,1.54),radius=.09,color="r")
circle8=plt.Circle((-2.5,5.7),radius=.5,color="black")
ax=plt.gca()
ax.add_patch(circle1)
ax.add_patch(circle2)
ax.add_patch(circle3)
ax.add_patch(circle4)
ax.add_patch(circle5)
ax.add_patch(circle6)
ax.add_patch(circle7)
ax.add_patch(circle8)
plt.axis("scaled")
plt.axis("equal")
plt.plot(x,y,"black",linewidth=3)
plt.plot(z,w,"black",linewidth=3)
plt.plot(a,b,"black",linewidth=6)
plt.plot(e,f,"black")
plt.plot(c,d,"black",linewidth=3)
plt.plot(g,h,"black",linewidth=3)
plt.plot(i,j,"black",linewidth=6)
plt.plot(k,l,"black")
plt.plot(m,n,"black")
plt.plot(o,p,"black")
plt.plot(q,r,"black")
plt.plot(s,t,"black")
plt.plot(u,v,"black",linewidth=2)
plt.plot(s1,t1,"black")
plt.plot(u1,v1,"black")
plt.plot(A,B,"black",linewidth=2)
plt.plot(C,D,"black",linewidth=2)
plt.plot(I,J,"r",linewidth=3)
plt.plot(K,L,"r",linewidth=4)
plt.plot(O,P,"r",linewidth=4)
plt.plot(x1,y1,"r",linewidth=4)
plt.plot(z1,w1,"r",linewidth=4)
plt.show()

# %%
x=np.linspace(-2.5,2.5,40)
y=(2**x)
z=np.linspace(-7.5,-2.5,40)
w=(.5**x)
a=np.linspace(-1,2,40)
b=-(0.6**a)+6
i=np.linspace(-7,-4,40)
j=-(.6/(.6**a))+6
e=np.linspace(-1,2,40)
f=-(.6**e)+5.5
k=np.linspace(-7,-4,40)
l=-(.6/(.6**e))+5.5
c=np.linspace(-2.5,2.5,40)
d=(.7**c)+5.5
g=np.linspace(-7.5,-2.5,40)
h=(1/((.7)**c))+5.5
m=np.linspace(0,2,40)
n=m+3
o=np.linspace(-5,-7,40)
p=-o-2
q=np.linspace(-1,0,40)
r=(.6**q)+2
s=np.linspace(-4,-5,40)
t=-(1.3/(.5**q))+4.3
u=np.linspace(-3.5,-1.5,40)
v=((x/3)**2)+5
s1=np.linspace(-2.5,-3,40)
t1=-(o/5)+1
u1=np.linspace(-2,-2.5,40)
v1=(u1/1)+4.5
A=np.linspace(-1.5,-2.5,40)
B=(x/3)+6.5
C=np.linspace(-3.5,-2.5,40)
D=(C/.65)+11.1
E=np.linspace(-3.5,-1.5,40)
F=((x/6)**2)+1.3
G=np.linspace(-3.2,-1.8,40)
H=((x/4)**2)+1
I=np.linspace(-3.2,-1.8,40)
J=((x/4)**2)+3.6
K=np.linspace(-2.3,-2.5,40)
L=(K/2)+2.85
O=np.linspace(-2.5,-2.7,40)
P=-(o/13)+1.18
M=np.linspace(-2.8,-2.2,40)
N=-((x/7)**2)+.75
x1=np.linspace(-2.7,-3.2,40)
y1=(x1/2)+3.08
z1=np.linspace(-2.3,-1.8,40)
w1=-(z1/2)+.6
circle1=plt.Circle((-2.5,4.3),radius=.35,edgecolor="r",facecolor="r",linewidth=3)
circle2=plt.Circle((0,3.8),radius=.5,color="black")
circle3=plt.Circle((-5,3.8),radius=.5,color="black")
circle4=plt.Circle((-1.3,2.5),radius=1,edgecolor="orange",facecolor="w",linewidth=2)
circle5=plt.Circle((-.7,1.69),radius=.09,color="r")
circle6=plt.Circle((-0.5,1.89),radius=.09,color="r")
circle7=plt.Circle((-.94,1.54),radius=.09,color="r")
circle8=plt.Circle((-2.5,5.7),radius=.5,color="black")
ax=plt.gca()
ax.add_patch(circle1)
ax.add_patch(circle2)
ax.add_patch(circle3)
ax.add_patch(circle4)
ax.add_patch(circle5)
ax.add_patch(circle6)
ax.add_patch(circle7)
ax.add_patch(circle8)
plt.axis("scaled")
plt.axis("equal")
plt.plot(x,y,"black",linewidth=3)
plt.plot(z,w,"black",linewidth=3)
plt.plot(a,b,"black",linewidth=6)
plt.plot(e,f,"black")
plt.plot(c,d,"black",linewidth=3)
plt.plot(g,h,"black",linewidth=3)
plt.plot(i,j,"black",linewidth=6)
plt.plot(k,l,"black")
plt.plot(m,n,"black")
plt.plot(o,p,"black")
plt.plot(q,r,"black")
plt.plot(s,t,"black")
plt.plot(u,v,"black",linewidth=2)
plt.plot(s1,t1,"black")
plt.plot(u1,v1,"black")
plt.plot(A,B,"black",linewidth=2)
plt.plot(C,D,"black",linewidth=2)
plt.plot(E,F,"r",linewidth=5)
plt.plot(I,J,"r",linewidth=3)
plt.plot(K,L,"r",linewidth=4)
plt.plot(O,P,"r",linewidth=4)
plt.plot(x1,y1,"r",linewidth=4)
plt.plot(z1,w1,"r",linewidth=4)
plt.show()

# %%
x=np.linspace(-2.5,2.5,40)
y=(2**x)
z=np.linspace(-7.5,-2.5,40)
w=(.5**x)
a=np.linspace(-1,2,40)
b=-(0.6**a)+6
i=np.linspace(-7,-4,40)
j=-(.6/(.6**a))+6
e=np.linspace(-1,2,40)
f=-(.6**e)+5.5
k=np.linspace(-7,-4,40)
l=-(.6/(.6**e))+5.5
c=np.linspace(-2.5,2.5,40)
d=(.7**c)+5.5
g=np.linspace(-7.5,-2.5,40)
h=(1/((.7)**c))+5.5
m=np.linspace(0,2,40)
n=m+3
o=np.linspace(-5,-7,40)
p=-o-2
q=np.linspace(-1,0,40)
r=(.6**q)+2
s=np.linspace(-4,-5,40)
t=-(1.3/(.5**q))+4.3
u=np.linspace(-3.5,-1.5,40)
v=((x/3)**2)+5
s1=np.linspace(-2.5,-3,40)
t1=-(o/5)+1
u1=np.linspace(-2,-2.5,40)
v1=(u1/1)+4.5
A=np.linspace(-1.5,-2.5,40)
B=(x/3)+6.5
C=np.linspace(-3.5,-2.5,40)
D=(C/.65)+11.1
E=np.linspace(-3.5,-1.5,40)
F=((x/6)**2)+1.3
G=np.linspace(-3.2,-1.8,40)
H=((x/4)**2)+1
I=np.linspace(-3.2,-1.8,40)
J=((x/4)**2)+3.6
K=np.linspace(-2.3,-2.5,40)
L=(K/2)+2.85
O=np.linspace(-2.5,-2.7,40)
P=-(o/13)+1.18
M=np.linspace(-2.8,-2.2,40)
N=-((x/7)**2)+.75
x1=np.linspace(-2.7,-3.2,40)
y1=(x1/2)+3.08
z1=np.linspace(-2.3,-1.8,40)
w1=-(z1/2)+.6
circle1=plt.Circle((-2.5,4.3),radius=.35,edgecolor="r",facecolor="r",linewidth=3)
circle2=plt.Circle((0,3.8),radius=.5,color="black")
circle3=plt.Circle((-5,3.8),radius=.5,color="black")
circle4=plt.Circle((-1.3,2.5),radius=1,edgecolor="orange",facecolor="w",linewidth=2)
circle5=plt.Circle((-.7,1.69),radius=.09,color="r")
circle6=plt.Circle((-0.5,1.89),radius=.09,color="r")
circle7=plt.Circle((-.94,1.54),radius=.09,color="r")
circle8=plt.Circle((-2.5,5.7),radius=.5,color="black")
ax=plt.gca()
ax.add_patch(circle1)
ax.add_patch(circle2)
ax.add_patch(circle3)
ax.add_patch(circle4)
ax.add_patch(circle5)
ax.add_patch(circle6)
ax.add_patch(circle7)
ax.add_patch(circle8)
plt.axis("scaled")
plt.axis("equal")
plt.plot(x,y,"black",linewidth=3)
plt.plot(z,w,"black",linewidth=3)
plt.plot(a,b,"black",linewidth=6)
plt.plot(e,f,"black")
plt.plot(c,d,"black",linewidth=3)
plt.plot(g,h,"black",linewidth=3)
plt.plot(i,j,"black",linewidth=6)
plt.plot(k,l,"black")
plt.plot(m,n,"black")
plt.plot(o,p,"black")
plt.plot(q,r,"black")
plt.plot(s,t,"black")
plt.plot(u,v,"black",linewidth=2)
plt.plot(s1,t1,"black")
plt.plot(u1,v1,"black")
plt.plot(A,B,"black",linewidth=2)
plt.plot(C,D,"black",linewidth=2)
plt.plot(E,F,"r",linewidth=5)
plt.plot(G,H,"r",linewidth=4)
plt.plot(I,J,"r",linewidth=3)
plt.plot(K,L,"r",linewidth=4)
plt.plot(O,P,"r",linewidth=4)
plt.plot(x1,y1,"r",linewidth=4)
plt.plot(z1,w1,"r",linewidth=4)
plt.show()

# %%
x=np.linspace(-2.5,2.5,40)
y=(2**x)
z=np.linspace(-7.5,-2.5,40)
w=(.5**x)
a=np.linspace(-1,2,40)
b=-(0.6**a)+6
i=np.linspace(-7,-4,40)
j=-(.6/(.6**a))+6
e=np.linspace(-1,2,40)
f=-(.6**e)+5.5
k=np.linspace(-7,-4,40)
l=-(.6/(.6**e))+5.5
c=np.linspace(-2.5,2.5,40)
d=(.7**c)+5.5
g=np.linspace(-7.5,-2.5,40)
h=(1/((.7)**c))+5.5
m=np.linspace(0,2,40)
n=m+3
o=np.linspace(-5,-7,40)
p=-o-2
q=np.linspace(-1,0,40)
r=(.6**q)+2
s=np.linspace(-4,-5,40)
t=-(1.3/(.5**q))+4.3
u=np.linspace(-3.5,-1.5,40)
v=((x/3)**2)+5
s1=np.linspace(-2.5,-3,40)
t1=-(o/5)+1
u1=np.linspace(-2,-2.5,40)
v1=(u1/1)+4.5
A=np.linspace(-1.5,-2.5,40)
B=(x/3)+6.5
C=np.linspace(-3.5,-2.5,40)
D=(C/.65)+11.1
E=np.linspace(-3.5,-1.5,40)
F=((x/6)**2)+1.3
G=np.linspace(-3.2,-1.8,40)
H=((x/4)**2)+1
I=np.linspace(-3.2,-1.8,40)
J=((x/4)**2)+3.6
K=np.linspace(-2.3,-2.5,40)
L=(K/2)+2.85
O=np.linspace(-2.5,-2.7,40)
P=-(o/13)+1.18
M=np.linspace(-2.8,-2.2,40)
N=-((x/7)**2)+.75
x1=np.linspace(-2.7,-3.2,40)
y1=(x1/2)+3.08
z1=np.linspace(-2.3,-1.8,40)
w1=-(z1/2)+.6
circle1=plt.Circle((-2.5,4.3),radius=.35,edgecolor="r",facecolor="r",linewidth=3)
circle2=plt.Circle((0,3.8),radius=.5,color="black")
circle3=plt.Circle((-5,3.8),radius=.5,color="black")
circle4=plt.Circle((-1.3,2.5),radius=1,edgecolor="orange",facecolor="w",linewidth=2)
circle5=plt.Circle((-.7,1.69),radius=.09,color="r")
circle6=plt.Circle((-0.5,1.89),radius=.09,color="r")
circle7=plt.Circle((-.94,1.54),radius=.09,color="r")
circle8=plt.Circle((-2.5,5.7),radius=.5,color="black")
cir=plt.Circle(())
ax=plt.gca()
ax.add_patch(circle1)
ax.add_patch(circle2)
ax.add_patch(circle3)
ax.add_patch(circle4)
ax.add_patch(circle5)
ax.add_patch(circle6)
ax.add_patch(circle7)
ax.add_patch(circle8)
plt.axis("scaled")
plt.axis("equal")
plt.plot(x,y,"black",linewidth=3)
plt.plot(z,w,"black",linewidth=3)
plt.plot(a,b,"black",linewidth=8)
plt.plot(e,f,"black")
plt.plot(c,d,"black",linewidth=3)
plt.plot(g,h,"black",linewidth=3)
plt.plot(i,j,"black",linewidth=8)
plt.plot(k,l,"black")
plt.plot(m,n,"black")
plt.plot(o,p,"black")
plt.plot(q,r,"black")
plt.plot(s,t,"black")
plt.plot(u,v,"black",linewidth=2)
plt.plot(s1,t1,"black")
plt.plot(u1,v1,"black")
plt.plot(A,B,"black",linewidth=2)
plt.plot(C,D,"black",linewidth=2)
plt.plot(E,F,"r",linewidth=5)
plt.plot(G,H,"r",linewidth=4)
plt.plot(I,J,"r",linewidth=3)
plt.plot(K,L,"r",linewidth=4)
plt.plot(O,P,"r",linewidth=4)
plt.plot(x1,y1,"r",linewidth=4)
plt.plot(z1,w1,"r",linewidth=4)
plt.plot(M,N,"black")
plt.show()

# %%
x=np.linspace(-2.5,2.5,40)
y=(2**x)
z=np.linspace(-7.5,-2.5,40)
w=(.5**x)
a=np.linspace(-1,2,40)
b=-(0.6**a)+6
i=np.linspace(-7,-4,40)
j=-(.6/(.6**a))+6
e=np.linspace(-1,2,40)
f=-(.6**e)+5.5
k=np.linspace(-7,-4,40)
l=-(.6/(.6**e))+5.5
c=np.linspace(-2.5,2.5,40)
d=(.7**c)+5.5
c1=np.linspace(-2.5,2.7,40)
d1=(.7**c1)+6
g=np.linspace(-7.5,-2.5,40)
h=(1/((.7)**c))+5.5
g1=np.linspace(-7.7,-2.5,40)
h1=(1/((.7)**x))+6
m=np.linspace(0,2,40)
n=m+3
o=np.linspace(-5,-7,40)
p=-o-2
q=np.linspace(-1,0,40)
r=(.6**q)+2
s=np.linspace(-4,-5,40)
t=-(1.3/(.5**q))+4.3
u=np.linspace(-3.5,-1.5,40)
v=((x/3)**2)+5
s1=np.linspace(-2.5,-3,40)
t1=-(o/5)+1
u1=np.linspace(-2,-2.5,40)
v1=(u1/1)+4.5
A=np.linspace(-1.5,-2.5,40)
B=(x/3)+6.5
C=np.linspace(-3.5,-2.5,40)
D=(C/.65)+11.1
E=np.linspace(-3.5,-1.5,40)
F=((x/6)**2)+1.3
G=np.linspace(-3.2,-1.8,40)
H=((x/4)**2)+1
I=np.linspace(-3.2,-1.8,40)
J=((x/4)**2)+3.6
K=np.linspace(-2.3,-2.5,40)
L=(K/2)+2.85
O=np.linspace(-2.5,-2.7,40)
P=-(o/13)+1.18
M=np.linspace(-2.8,-2.2,40)
N=-((x/7)**2)+.75
x1=np.linspace(-2.7,-3.2,40)
y1=(x1/2)+3.08
z1=np.linspace(-2.3,-1.8,40)
w1=-(z1/2)+.6
circle1=plt.Circle((-2.5,4.3),radius=.35,edgecolor="r",facecolor="r",linewidth=3)
circle2=plt.Circle((0,3.8),radius=.5,color="black")
circle3=plt.Circle((-5,3.8),radius=.5,color="black")
circle4=plt.Circle((-1.3,2.5),radius=1,edgecolor="orange",facecolor="w",linewidth=2)
circle5=plt.Circle((-.7,1.69),radius=.09,color="r")
circle6=plt.Circle((-0.5,1.89),radius=.09,color="r")
circle7=plt.Circle((-.94,1.54),radius=.09,color="r")
circle8=plt.Circle((-2.5,5.7),radius=.5,color="black")
ax=plt.gca()
ax.add_patch(circle1)
ax.add_patch(circle2)
ax.add_patch(circle3)
ax.add_patch(circle4)
ax.add_patch(circle5)
ax.add_patch(circle6)
ax.add_patch(circle7)
ax.add_patch(circle8)
plt.axis("scaled")
plt.axis("equal")
plt.plot(x,y,"black",linewidth=3)
plt.plot(z,w,"black",linewidth=3)
plt.plot(a,b,"black",linewidth=8)
plt.plot(e,f,"black")
plt.plot(c,d,"black",linewidth=3)
plt.plot(g,h,"black",linewidth=3)
plt.plot(c1,d1,"orange",linewidth=15)
plt.plot(g1,h1,"orange",linewidth=15)
plt.plot(i,j,"black",linewidth=8)
plt.plot(k,l,"black")
plt.plot(m,n,"black")
plt.plot(o,p,"black")
plt.plot(q,r,"black")
plt.plot(s,t,"black")
plt.plot(u,v,"black",linewidth=2)
plt.plot(s1,t1,"black")
plt.plot(u1,v1,"black")
plt.plot(A,B,"black",linewidth=2)
plt.plot(C,D,"black",linewidth=2)
plt.plot(E,F,"r",linewidth=5)
plt.plot(G,H,"r",linewidth=4)
plt.plot(I,J,"r",linewidth=3)
plt.plot(K,L,"r",linewidth=4)
plt.plot(O,P,"r",linewidth=4)
plt.plot(x1,y1,"r",linewidth=4)
plt.plot(z1,w1,"r",linewidth=4)
plt.plot(M,N,"black")
plt.show()
